# %%
import os
import sys

# 打印当前python.exe的完整路径（核心）
print("当前使用的python.exe路径：", sys.executable)
# 打印当前工作目录（相对路径的基准！）
print("代码执行的基准路径（工作目录）：", os.getcwd())
# 打印当前ipynb文件的实际存储路径（对比用）
print("ipynb文件自身的路径：", os.path.abspath(__file__) if '__file__' in locals() else os.path.abspath("."))
# Out:
# 当前使用的python.exe路径： D:\Anaconda3\envs\pytorch_env\python.exe
# 代码执行的基准路径（工作目录）： D:\pythonSpace\pytorchLearning
# ipynb文件自身的路径： D:\pythonSpace\pytorchLearning
